# %%
"""
HFSS joint dataset generation (L1,L2,L3,L4 together) with:
- Fast (Interpolating) Sweep
- Non-graphical mode (GUI OFF)
- Latin Hypercube sampling (LHS)  
"""

import numpy as np
import pandas as pd
from ansys.aedt.core import Desktop, Hfss

# %%
PROJECT_PATH = r"E:\Ansys Projects\Project1.aedt"
DESIGN_NAME  = "HFSSDesign1"

VERSION = "2025.2"
STUDENT_VERSION = True

SETUP = "Setup1"
SWEEP = "Sweep"

F_LOW_GHZ  = 0.6
F_HIGH_GHZ = 2.4
N_FREQ     = 451

N_SAMPLES = 1800
SEED = 42

BOUNDS_IN = {
    "L1": (-1.7, -0.5),
    "L2": (0.5,  1.818),
    "L3": (-1.818, -1.0),
    "L4": (0.5,  1.818),
}

OUTPUT_CSV = "hfss_joint_dataset_bandpass_3.csv"

CHECKPOINT_EVERY = 25

# %%
def lhs_samples(n, bounds_dict, seed=0):
    rng = np.random.default_rng(seed)
    keys = list(bounds_dict.keys())
    d = len(keys)

    u = np.zeros((n, d), dtype=float)
    for j in range(d):
        perm = rng.permutation(n)
        u[:, j] = (perm + rng.random(n)) / n

    out = {}
    for j, k in enumerate(keys):
        lo, hi = bounds_dict[k]
        out[k] = lo + u[:, j] * (hi - lo)
    return out

def to_ghz(freq_array):
    f = np.asarray(freq_array, dtype=float)
    if np.nanmax(f) > 1e6:   
        return f / 1e9
    return f

def bandpass_metrics(freqs_ghz, s21_db, s11_db,
                     f_low=F_LOW_GHZ, f_high=F_HIGH_GHZ,
                     bw_drop_db=3.0):
  
    freqs_ghz = np.asarray(freqs_ghz, float)
    s21_db = np.asarray(s21_db, float)
    s11_db = np.asarray(s11_db, float)

    band = (freqs_ghz >= f_low) & (freqs_ghz <= f_high)
    if band.sum() < 3:
        return np.nan, 0.0, np.nan, np.nan, np.nan

    f = freqs_ghz[band]
    s21 = s21_db[band]
    s11 = s11_db[band]

    i0 = int(np.nanargmax(s21))
    f0 = float(f[i0])
    s21_pk = float(s21[i0])
    il_db = float(-s21_pk)   

    thr = s21_pk - bw_drop_db
    above = s21 >= thr
    if not above[i0]:
        return f0, 0.0, il_db, np.nan, np.nan

    left = i0
    while left - 1 >= 0 and above[left - 1]:
        left -= 1
    right = i0
    while right + 1 < len(f) and above[right + 1]:
        right += 1

    def interp_edge(i_a, i_b):
        fa, fb = float(f[i_a]), float(f[i_b])
        ya, yb = float(s21[i_a]), float(s21[i_b])
        if np.isclose(ya, yb):
            return fa
        t = (thr - ya) / (yb - ya)
        return fa + t * (fb - fa)

    fL = float(f[0]) if left == 0 else float(interp_edge(left - 1, left))
    fR = float(f[-1]) if right == len(f) - 1 else float(interp_edge(right, right + 1))
    bw = float(max(0.0, fR - fL))

    pb_s11 = s11[left:right + 1]
    rl_vals = -pb_s11   
    rl_worst = float(np.nanmin(rl_vals))   
    rl_avg = float(np.nanmean(rl_vals))

    return f0, bw, il_db, rl_worst, rl_avg

# %%
desktop = Desktop(
    version="2025.2",
    non_graphical=True,       
    new_desktop=True,
    student_version=True
)

hfss = Hfss(
    project=PROJECT_PATH,
    design="HFSSDesign1",
    version="2025.2"
)

print("Connected to:", hfss.project_name, "/", hfss.design_name)
# Out:
# PyAEDT INFO: Python version 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)].
# PyAEDT INFO: PyAEDT version 0.23.0.
# PyAEDT INFO: Initializing new Desktop session.
# PyAEDT INFO: Log on console is enabled.
# PyAEDT INFO: Log on file C:\Users\Papa\AppData\Local\Temp\pyaedt_Papa_4eedd21d-23f2-405d-9f15-b80ea8a54eab.log is enabled.
# PyAEDT INFO: Log on AEDT is disabled.
# PyAEDT INFO: Starting new AEDT gRPC session.
# PyAEDT INFO: AEDT installation Path E:\ANSYS Inc\ANSYS Student\v252\AnsysEM
# PyAEDT INFO: Client application successfully started.
# PyAEDT INFO: New AEDT gRPC session session started on port 50051.
# PyAEDT INFO: 2025.2SV Student version started with process ID 22032.
# PyAEDT WARNING: Service Pack is not detected. PyAEDT is currently connecting in Insecure Mode.
# PyAEDT WARNING: Please download and install latest Service Pack to use connect to AEDT in Secure Mode.
# PyAEDT INFO: Debug logger is disabled. PyAEDT methods will not be logged.
# PyAEDT INFO: Parsing E:\Ansys Projects\Project1.aedt.
# PyAEDT INFO: Python version 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)].
# PyAEDT INFO: PyAEDT version 0.23.0.
# PyAEDT INFO: Returning found Desktop session with PID 22032!
# PyAEDT INFO: File E:\Ansys Projects\Project1.aedt correctly loaded. Elapsed time: 0m 0sec
# PyAEDT INFO: Project Project1 has been opened.
# PyAEDT INFO: Active Design set to HFSSDesign1
# PyAEDT INFO: Aedt Objects correctly read
# Connected to: Project1 / HFSSDesign1

# %%
setup = hfss.get_setup(SETUP)
setup.props["SaveFields"] = False
setup.props["SaveRadFields"] = False
setup.props["MaximumPasses"] = 3
setup.props["MinimumConvergedPasses"] = 1
setup.update()



hfss.create_linear_count_sweep(
    setup=SETUP,
    units="GHz",
    sweepname=SWEEP,
    start_frequency=F_LOW_GHZ,
    stop_frequency=F_HIGH_GHZ,
    num_of_freq_points=N_FREQ,
    sweep_type="Fast"
)
# Out:
# PyAEDT WARNING: Argument `sweepname` is deprecated for method `create_linear_count_sweep`; use `name` instead.
# PyAEDT WARNING: Parameter 'ID' is invalid and will be ignored.
# PyAEDT WARNING: Sweep Sweep is already present. Sweep has been renamed in Sweep_98VAGD.
# PyAEDT INFO: Linear count sweep Sweep_98VAGD has been correctly created.
# Setup1 : Sweep_98VAGD

# %%
samples = lhs_samples(N_SAMPLES, BOUNDS_IN, seed=SEED)

rows = []
cols = [
    "L1_in", "L2_in", "L3_in", "L4_in",
    "f0_GHz", "BW3dB_GHz", "IL_dB", "RL_worst_dB", "RL_avg_dB",
    "status", "error"
]

for i in range(N_SAMPLES):
    L1 = float(samples["L1"][i])
    L2 = float(samples["L2"][i])
    L3 = float(samples["L3"][i])
    L4 = float(samples["L4"][i])

    print(f"[{i+1}/{N_SAMPLES}] L1={L1:.4f}in L2={L2:.4f}in L3={L3:.4f}in L4={L4:.4f}in")

    try:
        hfss["L1"] = f"{L1}in"
        hfss["L2"] = f"{L2}in"
        hfss["L3"] = f"{L3}in"
        hfss["L4"] = f"{L4}in"

        hfss.analyze_setup(SETUP)

        sol = hfss.post.get_solution_data(
            expressions=["S(1,1)", "S(2,1)"],   
            setup_sweep_name=f"{SETUP} : {SWEEP}"
        )

        freqs = to_ghz(sol.primary_sweep_values)

        try:
            s11_db = np.array(sol.data_db20("S(1,1)"), float)
            s21_db = np.array(sol.data_db20("S(2,1)"), float)
        except Exception:
            _, s11_db = sol.get_expression_data("S(1,1)", formula="db20")
            _, s21_db = sol.get_expression_data("S(2,1)", formula="db20")
            s11_db = np.array(s11_db, float)
            s21_db = np.array(s21_db, float)

        f0, bw, il, rl_worst, rl_avg = bandpass_metrics(freqs, s21_db, s11_db)

        rows.append([L1, L2, L3, L4, f0, bw, il, rl_worst, rl_avg, "OK", ""])

    except Exception as e:
        rows.append([L1, L2, L3, L4, np.nan, 0.0, np.nan, np.nan, np.nan, "FAIL", str(e)])
        print("  -> FAIL:", e)

    # checkpoint save
    if (i + 1) % CHECKPOINT_EVERY == 0:
        pd.DataFrame(rows, columns=cols).to_csv(OUTPUT_CSV, index=False)
        print(f"  [checkpoint] wrote {len(rows)} rows to {OUTPUT_CSV}")
# Out:
# [1/1800] L1=-1.5984in L2=0.8328in L3=-1.0808in L4=1.7586in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: PostProcessor class has been initialized! Elapsed time: 0m 0sec
# PyAEDT INFO: PostProcessor class has been initialized! Elapsed time: 0m 0sec
# PyAEDT INFO: Post class has been initialized! Elapsed time: 0m 0sec
# PyAEDT INFO: Modeler class has been initialized! Elapsed time: 0m 0sec
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005994081497192383
# Time to initialize solution data:0.010987997055053711
# [2/1800] L1=-1.6064in L2=0.7422in L3=-1.4394in L4=0.7835in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01583409309387207
# [3/1800] L1=-1.4970in L2=1.3744in L3=-1.3842in L4=1.4585in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015113592147827148
# [4/1800] L1=-1.4289in L2=1.8137in L3=-1.1115in L4=0.5898in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.012653350830078125
# Time to initialize solution data:0.018540382385253906
# [5/1800] L1=-1.1020in L2=1.5007in L3=-1.4570in L4=0.5407in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01229548454284668
# [6/1800] L1=-0.9920in L2=0.9833in L3=-1.2979in L4=0.7716in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.010936498641967773
# [7/1800] L1=-0.9044in L2=1.0227in L3=-1.7769in L4=1.5631in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016208887100219727
# [8/1800] L1=-0.8084in L2=1.6347in L3=-1.7261in L4=1.4927in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015692472457885742
# [9/1800] L1=-1.5837in L2=1.7374in L3=-1.6729in L4=0.8837in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01928853988647461
# [10/1800] L1=-0.8176in L2=1.6879in L3=-1.7296in L4=1.0254in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.003536224365234375
# Time to initialize solution data:0.013210773468017578
# [11/1800] L1=-0.8350in L2=1.2011in L3=-1.0502in L4=0.5878in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006559133529663086
# Time to initialize solution data:0.01275944709777832
# [12/1800] L1=-0.9309in L2=0.9787in L3=-1.4776in L4=1.3599in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0197141170501709
# Time to initialize solution data:0.024709224700927734
# [13/1800] L1=-1.6496in L2=0.5705in L3=-1.4415in L4=0.9452in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012549638748168945
# [14/1800] L1=-1.2738in L2=1.5987in L3=-1.5505in L4=1.3557in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01378488540649414
# [15/1800] L1=-0.9611in L2=1.3865in L3=-1.5527in L4=0.8999in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012182235717773438
# [16/1800] L1=-0.9291in L2=1.4292in L3=-1.2535in L4=1.7957in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0060198307037353516
# Time to initialize solution data:0.010724544525146484
# [17/1800] L1=-0.7586in L2=0.9684in L3=-1.5169in L4=0.8549in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625953674316406
# Time to initialize solution data:0.024460792541503906
# [18/1800] L1=-0.5232in L2=0.6707in L3=-1.1302in L4=0.7607in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.011043548583984375
# [19/1800] L1=-1.4522in L2=0.7537in L3=-1.7741in L4=1.2032in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.016269207000732422
# Time to initialize solution data:0.025290966033935547
# [20/1800] L1=-1.4897in L2=0.9595in L3=-1.4931in L4=1.6713in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0156252384185791
# Time to initialize solution data:0.02012157440185547
# [21/1800] L1=-0.9392in L2=1.3524in L3=-1.0423in L4=1.7259in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.01575016975402832
# Time to initialize solution data:0.020743608474731445
# [22/1800] L1=-1.1710in L2=1.0055in L3=-1.6858in L4=0.7807in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01869058609008789
# [23/1800] L1=-1.5168in L2=0.5559in L3=-1.0686in L4=0.6052in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014093160629272461
# [24/1800] L1=-1.1125in L2=1.5852in L3=-1.2921in L4=0.9135in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014175891876220703
# [25/1800] L1=-1.5328in L2=0.9229in L3=-1.6761in L4=0.5487in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01036214828491211
#   [checkpoint] wrote 25 rows to hfss_joint_dataset_bandpass_3.csv
# [26/1800] L1=-1.1054in L2=1.7757in L3=-1.2682in L4=1.2380in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.022624492645263672
# [27/1800] L1=-0.9776in L2=1.6207in L3=-1.0584in L4=0.9129in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.02276778221130371
# [28/1800] L1=-0.9402in L2=0.7249in L3=-1.4098in L4=0.7888in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006992340087890625
# Time to initialize solution data:0.011988162994384766
# [29/1800] L1=-0.8133in L2=1.4458in L3=-1.2091in L4=1.0661in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0069925785064697266
# Time to initialize solution data:0.010988235473632812
# [30/1800] L1=-1.3774in L2=1.5231in L3=-1.1589in L4=1.0534in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.009989500045776367
# [31/1800] L1=-0.8257in L2=0.5395in L3=-1.4388in L4=1.6805in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.022761106491088867
# [32/1800] L1=-1.3181in L2=1.1825in L3=-1.1939in L4=1.1948in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017609596252441406
# [33/1800] L1=-1.2056in L2=1.5687in L3=-1.5396in L4=1.3520in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.010400056838989258
# [34/1800] L1=-0.5627in L2=1.0516in L3=-1.7401in L4=0.5955in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00592350959777832
# Time to initialize solution data:0.010042428970336914
# [35/1800] L1=-1.6166in L2=0.6188in L3=-1.2280in L4=1.6639in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006992340087890625
# Time to initialize solution data:0.011988162994384766
# [36/1800] L1=-0.9249in L2=1.1183in L3=-1.7964in L4=0.8746in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006992340087890625
# Time to initialize solution data:0.012279272079467773
# [37/1800] L1=-1.4136in L2=0.7606in L3=-1.2268in L4=1.2637in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.021023988723754883
# [38/1800] L1=-1.6466in L2=0.7943in L3=-1.7910in L4=1.3173in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011617422103881836
# [39/1800] L1=-1.0735in L2=0.7316in L3=-1.0918in L4=1.3815in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012694120407104492
# [40/1800] L1=-0.5534in L2=1.0288in L3=-1.0716in L4=0.6963in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.024585485458374023
# [41/1800] L1=-0.7943in L2=1.5930in L3=-1.5300in L4=0.5357in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013087749481201172
# [42/1800] L1=-1.6684in L2=1.8067in L3=-1.5084in L4=0.5951in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.018555164337158203
# [43/1800] L1=-1.1993in L2=1.5209in L3=-1.6586in L4=0.9316in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.023560523986816406
# [44/1800] L1=-1.6308in L2=1.7754in L3=-1.6075in L4=1.4358in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.021715402603149414
# Time to initialize solution data:0.0257112979888916
# [45/1800] L1=-1.0504in L2=1.5606in L3=-1.6689in L4=1.0476in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016503334045410156
# [46/1800] L1=-0.8267in L2=0.6198in L3=-1.4603in L4=1.2819in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013299942016601562
# [47/1800] L1=-1.2298in L2=0.7338in L3=-1.3935in L4=0.5779in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.023206472396850586
# [48/1800] L1=-1.5430in L2=1.0876in L3=-1.3395in L4=1.7481in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.025769472122192383
# [49/1800] L1=-1.4012in L2=0.6663in L3=-1.8021in L4=1.3324in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015342950820922852
# [50/1800] L1=-0.6132in L2=1.3001in L3=-1.7481in L4=1.2221in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006039142608642578
# Time to initialize solution data:0.011034488677978516
#   [checkpoint] wrote 50 rows to hfss_joint_dataset_bandpass_3.csv
# [51/1800] L1=-0.9488in L2=0.8186in L3=-1.8030in L4=0.6308in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0069925785064697266
# Time to initialize solution data:0.010988950729370117
# [52/1800] L1=-0.7537in L2=0.6089in L3=-1.6345in L4=0.9763in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019738435745239258
# [53/1800] L1=-0.7143in L2=0.9128in L3=-1.5514in L4=1.6915in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.002017974853515625
# Time to initialize solution data:0.010526180267333984
# [54/1800] L1=-0.7194in L2=1.0622in L3=-1.0630in L4=0.5138in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.010994672775268555
# [55/1800] L1=-0.9360in L2=1.7375in L3=-1.1556in L4=0.9908in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0069925785064697266
# Time to initialize solution data:0.01109933853149414
# [56/1800] L1=-1.3714in L2=1.5224in L3=-1.7727in L4=1.4489in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 40.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.019694805145263672
# Time to initialize solution data:0.02469015121459961
# [57/1800] L1=-1.4459in L2=0.6534in L3=-1.3058in L4=1.4223in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012039899826049805
# [58/1800] L1=-1.2376in L2=0.6234in L3=-1.4819in L4=1.0159in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.020070791244506836
# [59/1800] L1=-0.7434in L2=0.7789in L3=-1.3228in L4=1.0905in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014199018478393555
# [60/1800] L1=-0.9771in L2=0.9359in L3=-1.6248in L4=0.5969in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.01680278778076172
# Time to initialize solution data:0.020798444747924805
# [61/1800] L1=-0.8813in L2=1.5558in L3=-1.6092in L4=1.7154in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015597105026245117
# [62/1800] L1=-1.2381in L2=0.5982in L3=-1.5133in L4=0.5935in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012407779693603516
# [63/1800] L1=-1.1443in L2=0.8971in L3=-1.6282in L4=1.1025in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015735149383544922
# Time to initialize solution data:0.02072906494140625
# [64/1800] L1=-1.0856in L2=0.5044in L3=-1.4640in L4=0.9389in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011649608612060547
# [65/1800] L1=-1.0840in L2=1.3990in L3=-1.1996in L4=1.2888in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.01680755615234375
# Time to initialize solution data:0.020803213119506836
# [66/1800] L1=-0.5783in L2=0.9944in L3=-1.6700in L4=1.4761in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016686677932739258
# [67/1800] L1=-1.3244in L2=0.7023in L3=-1.0379in L4=0.7341in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011167526245117188
# [68/1800] L1=-0.7491in L2=1.4115in L3=-1.0352in L4=1.5679in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.017671585083007812
# Time to initialize solution data:0.0216672420501709
# [69/1800] L1=-0.5097in L2=1.5021in L3=-1.2583in L4=1.4281in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.004014015197753906
# Time to initialize solution data:0.01116943359375
# [70/1800] L1=-1.0966in L2=1.3875in L3=-1.2140in L4=1.1864in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.002016782760620117
# Time to initialize solution data:0.010726451873779297
# [71/1800] L1=-1.0981in L2=1.0880in L3=-1.5918in L4=1.0209in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016787052154541016
# [72/1800] L1=-1.0621in L2=1.3666in L3=-1.1637in L4=1.4744in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.0204622745513916
# [73/1800] L1=-0.5131in L2=0.8898in L3=-1.3283in L4=0.7772in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019719600677490234
# [74/1800] L1=-1.6811in L2=0.6371in L3=-1.2505in L4=0.5996in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.02294325828552246
# [75/1800] L1=-0.9141in L2=0.6872in L3=-1.7404in L4=1.2331in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017020702362060547
#   [checkpoint] wrote 75 rows to hfss_joint_dataset_bandpass_3.csv
# [76/1800] L1=-0.9067in L2=1.1482in L3=-1.6929in L4=1.6800in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013625860214233398
# [77/1800] L1=-1.0263in L2=0.7274in L3=-1.5944in L4=0.5425in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993366241455078
# Time to initialize solution data:0.011036872863769531
# [78/1800] L1=-1.2310in L2=1.1373in L3=-1.1963in L4=0.7349in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006039857864379883
# Time to initialize solution data:0.010036230087280273
# [79/1800] L1=-0.5795in L2=1.5575in L3=-1.5783in L4=0.9420in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005992889404296875
# Time to initialize solution data:0.010250568389892578
# [80/1800] L1=-1.2086in L2=0.6810in L3=-1.4938in L4=1.3797in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.0260772705078125
# [81/1800] L1=-0.9656in L2=0.5990in L3=-1.6648in L4=1.6780in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624046325683594
# Time to initialize solution data:0.02300405502319336
# [82/1800] L1=-0.7217in L2=1.4753in L3=-1.5793in L4=1.2267in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006032466888427734
# Time to initialize solution data:0.010029077529907227
# [83/1800] L1=-0.9236in L2=1.1790in L3=-1.0444in L4=1.0259in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.01098942756652832
# [84/1800] L1=-0.6606in L2=1.0425in L3=-1.5582in L4=0.8555in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01482844352722168
# [85/1800] L1=-1.3604in L2=0.5321in L3=-1.2096in L4=1.6196in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.010497808456420898
# [86/1800] L1=-1.5010in L2=1.0707in L3=-1.2889in L4=1.6825in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.022397279739379883
# [87/1800] L1=-1.3292in L2=0.5744in L3=-1.3408in L4=1.7270in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01852726936340332
# [88/1800] L1=-1.4366in L2=0.8409in L3=-1.8098in L4=0.7510in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017778873443603516
# [89/1800] L1=-1.0705in L2=1.7527in L3=-1.0090in L4=1.3918in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.018106698989868164
# [90/1800] L1=-0.8504in L2=1.2353in L3=-1.6438in L4=0.9838in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.020813941955566406
# [91/1800] L1=-1.3866in L2=0.9147in L3=-1.6271in L4=0.5223in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013487815856933594
# [92/1800] L1=-1.1920in L2=1.3027in L3=-1.5602in L4=1.1532in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015625476837158203
# [93/1800] L1=-0.9057in L2=1.0243in L3=-1.0037in L4=0.5332in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017740726470947266
# [94/1800] L1=-0.8948in L2=1.4873in L3=-1.1175in L4=0.7452in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0020182132720947266
# Time to initialize solution data:0.010779142379760742
# [95/1800] L1=-1.3347in L2=0.7840in L3=-1.4050in L4=1.6942in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006154537200927734
# Time to initialize solution data:0.011149168014526367
# [96/1800] L1=-1.2019in L2=1.7447in L3=-1.0590in L4=1.1339in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014312028884887695
# [97/1800] L1=-1.2036in L2=0.6875in L3=-1.6416in L4=0.6752in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012768030166625977
# [98/1800] L1=-0.5754in L2=0.8049in L3=-1.5958in L4=1.6827in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011831283569335938
# [99/1800] L1=-1.0516in L2=1.3167in L3=-1.0598in L4=1.5397in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019574880599975586
# [100/1800] L1=-1.1684in L2=1.6910in L3=-1.6846in L4=0.6773in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01177215576171875
#   [checkpoint] wrote 100 rows to hfss_joint_dataset_bandpass_3.csv
# [101/1800] L1=-1.5797in L2=1.7166in L3=-1.5117in L4=1.5014in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 40.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.025812149047851562
# [102/1800] L1=-1.1133in L2=1.0089in L3=-1.7064in L4=0.6248in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016417264938354492
# [103/1800] L1=-1.0236in L2=1.2299in L3=-1.7165in L4=0.8048in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.024645328521728516
# [104/1800] L1=-1.5107in L2=1.2864in L3=-1.5642in L4=1.5329in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00601506233215332
# Time to initialize solution data:0.010688066482543945
# [105/1800] L1=-1.6674in L2=1.4385in L3=-1.7494in L4=0.6545in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013319253921508789
# [106/1800] L1=-0.8246in L2=1.0994in L3=-1.2472in L4=0.6258in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.02112412452697754
# [107/1800] L1=-1.4935in L2=1.2494in L3=-1.3808in L4=1.3966in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011656522750854492
# [108/1800] L1=-0.5365in L2=1.3145in L3=-1.3223in L4=0.5413in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014792203903198242
# [109/1800] L1=-1.3821in L2=0.8164in L3=-1.5882in L4=0.8199in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011257410049438477
# [110/1800] L1=-0.6760in L2=1.4984in L3=-1.4343in L4=1.6449in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.02309250831604004
# [111/1800] L1=-0.7060in L2=0.7563in L3=-1.3766in L4=0.7017in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 30.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013584613800048828
# [112/1800] L1=-0.5441in L2=0.8550in L3=-1.1651in L4=1.2415in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0030481815338134766
# Time to initialize solution data:0.011278152465820312
# [113/1800] L1=-1.4039in L2=1.6287in L3=-1.7190in L4=0.8494in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014974594116210938
# [114/1800] L1=-0.6873in L2=0.9067in L3=-1.7347in L4=1.5120in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.010988473892211914
# [115/1800] L1=-1.5101in L2=1.6359in L3=-1.1421in L4=1.7820in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013241291046142578
# [116/1800] L1=-0.6679in L2=1.4094in L3=-1.2882in L4=0.7721in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013455867767333984
# [117/1800] L1=-1.4650in L2=0.9878in L3=-1.5422in L4=0.7410in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0026335716247558594
# Time to initialize solution data:0.0026335716247558594
# [118/1800] L1=-1.4467in L2=1.6160in L3=-1.2036in L4=0.7235in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.023381471633911133
# [119/1800] L1=-0.6250in L2=0.8677in L3=-1.0567in L4=1.2454in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012489080429077148
# [120/1800] L1=-1.2557in L2=1.3601in L3=-1.5494in L4=1.2810in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015623331069946289
# Time to initialize solution data:0.022949695587158203
# [121/1800] L1=-0.7170in L2=1.4555in L3=-1.4270in L4=0.8029in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015531778335571289
# [122/1800] L1=-1.1860in L2=1.6820in L3=-1.3098in L4=1.1766in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017772674560546875
# [123/1800] L1=-1.3334in L2=0.8104in L3=-1.4172in L4=1.5976in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019469738006591797
# [124/1800] L1=-0.7805in L2=0.9798in L3=-1.5299in L4=1.7220in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.023129940032958984
# [125/1800] L1=-0.8492in L2=1.1016in L3=-1.6187in L4=0.5707in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.02411174774169922
#   [checkpoint] wrote 125 rows to hfss_joint_dataset_bandpass_3.csv
# [126/1800] L1=-1.0258in L2=1.7119in L3=-1.6744in L4=0.7140in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011265993118286133
# [127/1800] L1=-1.3280in L2=1.2311in L3=-1.6635in L4=1.8112in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013931989669799805
# [128/1800] L1=-1.0753in L2=1.0548in L3=-1.1360in L4=0.9297in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.025082111358642578
# [129/1800] L1=-1.3041in L2=0.5590in L3=-1.7658in L4=1.4268in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.020606517791748047
# [130/1800] L1=-1.4662in L2=0.5544in L3=-1.8143in L4=1.0323in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006037473678588867
# Time to initialize solution data:0.010869503021240234
# [131/1800] L1=-0.9614in L2=0.5599in L3=-1.6820in L4=0.5232in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 31.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.02063727378845215
# [132/1800] L1=-1.1187in L2=0.6083in L3=-1.5740in L4=1.7838in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.010240554809570312
# [133/1800] L1=-1.1148in L2=1.6184in L3=-1.5844in L4=0.7098in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0059931278228759766
# Time to initialize solution data:0.010861873626708984
# [134/1800] L1=-0.5554in L2=1.1631in L3=-1.0250in L4=0.9370in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005053043365478516
# Time to initialize solution data:0.010989665985107422
# [135/1800] L1=-1.1139in L2=1.0988in L3=-1.1059in L4=0.7162in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01773667335510254
# [136/1800] L1=-1.5315in L2=1.3803in L3=-1.1740in L4=0.6803in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.023597002029418945
# [137/1800] L1=-0.7296in L2=0.9180in L3=-1.4861in L4=0.7568in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011359930038452148
# [138/1800] L1=-0.9243in L2=0.6957in L3=-1.0785in L4=1.4778in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012648344039916992
# [139/1800] L1=-0.9914in L2=1.5542in L3=-1.7313in L4=0.7664in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011950016021728516
# [140/1800] L1=-1.3620in L2=1.4000in L3=-1.7320in L4=1.2001in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.01674962043762207
# Time to initialize solution data:0.020745277404785156
# [141/1800] L1=-0.5282in L2=1.1050in L3=-1.6722in L4=1.7421in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.010988950729370117
# [142/1800] L1=-0.6023in L2=1.0173in L3=-1.3310in L4=0.9520in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01326608657836914
# [143/1800] L1=-1.0764in L2=0.6051in L3=-1.5692in L4=1.1800in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.010734319686889648
# [144/1800] L1=-1.5571in L2=1.4906in L3=-1.6039in L4=1.2665in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.0
# [145/1800] L1=-1.4371in L2=1.3120in L3=-1.6062in L4=1.8139in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 39.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.010988712310791016
# [146/1800] L1=-1.6451in L2=1.5830in L3=-1.6505in L4=0.9514in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.02123546600341797
# [147/1800] L1=-1.4619in L2=1.4960in L3=-1.8019in L4=1.2843in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 41.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014635801315307617
# [148/1800] L1=-0.7573in L2=1.7912in L3=-1.1871in L4=1.5483in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016735315322875977
# [149/1800] L1=-1.1375in L2=1.2619in L3=-1.1814in L4=1.0440in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.010988712310791016
# [150/1800] L1=-1.2684in L2=1.5679in L3=-1.4541in L4=1.4071in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 40.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993843078613281
# Time to initialize solution data:0.009989738464355469
#   [checkpoint] wrote 150 rows to hfss_joint_dataset_bandpass_3.csv
# [151/1800] L1=-1.1580in L2=1.0337in L3=-1.5145in L4=0.9439in
# PyAEDT INFO: Solving design setup Setup1
# ...
# Time to initialize solution data:0.0
# Time to initialize solution data:0.016052722930908203
# [182/1800] L1=-0.8336in L2=1.4171in L3=-1.1016in L4=1.5054in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0036678314208984375
# Time to initialize solution data:0.0036678314208984375
# [183/1800] L1=-1.5452in L2=0.6404in L3=-1.0122in L4=1.0612in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.024531841278076172
# [184/1800] L1=-1.2571in L2=0.6474in L3=-1.0068in L4=0.5883in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01583552360534668
# [185/1800] L1=-1.6282in L2=1.0950in L3=-1.3863in L4=0.9575in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.024181127548217773
# [186/1800] L1=-0.8522in L2=0.7867in L3=-1.3213in L4=1.1413in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.024625539779663086
# [187/1800] L1=-1.1050in L2=1.4347in L3=-1.7204in L4=1.0519in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.022439956665039062
# [188/1800] L1=-1.5512in L2=1.7024in L3=-1.6160in L4=1.3936in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 42.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015311717987060547
# [189/1800] L1=-1.6022in L2=1.2481in L3=-1.6827in L4=1.7141in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 39.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.002017974853515625
# Time to initialize solution data:0.010803937911987305
# [190/1800] L1=-1.5532in L2=1.3017in L3=-1.4431in L4=0.9479in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.006127834320068359
# Time to initialize solution data:0.010123968124389648
# [191/1800] L1=-1.5067in L2=0.9080in L3=-1.4496in L4=0.6817in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013846397399902344
# [192/1800] L1=-0.8565in L2=1.5840in L3=-1.3899in L4=0.8402in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0059926509857177734
# Time to initialize solution data:0.01098775863647461
# [193/1800] L1=-1.3373in L2=1.3479in L3=-1.3204in L4=1.6012in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 40.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.024095535278320312
# [194/1800] L1=-1.3850in L2=1.0785in L3=-1.4679in L4=1.7869in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624284744262695
# Time to initialize solution data:0.02254629135131836
# [195/1800] L1=-1.6830in L2=1.2286in L3=-1.4658in L4=0.5305in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011785507202148438
# [196/1800] L1=-1.6043in L2=0.7574in L3=-1.4246in L4=1.0716in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013547420501708984
# [197/1800] L1=-1.3557in L2=1.6806in L3=-1.3975in L4=1.6319in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 46.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012614965438842773
# [198/1800] L1=-1.6653in L2=1.5400in L3=-1.2313in L4=0.9096in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.02443099021911621
# [199/1800] L1=-1.4230in L2=1.8180in L3=-1.2523in L4=1.1088in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.017672061920166016
# [200/1800] L1=-1.1537in L2=0.7089in L3=-1.3720in L4=0.9658in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.012900352478027344
#   [checkpoint] wrote 200 rows to hfss_joint_dataset_bandpass_3.csv
# [201/1800] L1=-1.2731in L2=0.9033in L3=-1.6804in L4=1.0028in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624523162841797
# Time to initialize solution data:0.022038936614990234
# [202/1800] L1=-1.2206in L2=1.6454in L3=-1.4814in L4=1.6352in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 41.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019299983978271484
# [203/1800] L1=-0.5643in L2=1.1320in L3=-1.4057in L4=0.6029in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.024924039840698242
# [204/1800] L1=-0.9385in L2=1.6003in L3=-1.1686in L4=1.2364in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.015756607055664062
# [205/1800] L1=-0.8669in L2=0.6831in L3=-1.1262in L4=1.3223in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005025386810302734
# Time to initialize solution data:0.011014461517333984
# [206/1800] L1=-1.6446in L2=1.5256in L3=-1.7747in L4=1.7884in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 42.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01497340202331543
# [207/1800] L1=-1.3387in L2=1.4682in L3=-1.0624in L4=1.7639in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0156252384185791
# Time to initialize solution data:0.022709369659423828
# [208/1800] L1=-0.7050in L2=1.3360in L3=-1.1778in L4=1.7054in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011688709259033203
# [209/1800] L1=-0.8634in L2=1.3177in L3=-1.6879in L4=0.8984in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.013914346694946289
# [210/1800] L1=-1.2217in L2=1.3089in L3=-1.4697in L4=0.7227in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.021061182022094727
# [211/1800] L1=-0.5026in L2=1.4094in L3=-1.3776in L4=0.5293in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993366241455078
# Time to initialize solution data:0.009990453720092773
# [212/1800] L1=-0.5815in L2=0.9970in L3=-1.8134in L4=0.6318in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.025333404541015625
# [213/1800] L1=-0.6376in L2=1.2666in L3=-1.0824in L4=1.3667in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011806011199951172
# [214/1800] L1=-1.5601in L2=1.1614in L3=-1.0519in L4=0.7985in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 32.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.023541688919067383
# [215/1800] L1=-1.2137in L2=1.7296in L3=-1.3164in L4=1.0878in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019420862197875977
# [216/1800] L1=-1.0376in L2=1.1808in L3=-1.7325in L4=1.4533in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.020165681838989258
# [217/1800] L1=-1.4714in L2=1.2455in L3=-1.5560in L4=1.6024in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.014972925186157227
# [218/1800] L1=-1.6862in L2=1.3264in L3=-1.7519in L4=0.8866in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01457071304321289
# [219/1800] L1=-0.6911in L2=1.1244in L3=-1.7176in L4=1.8149in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.011115789413452148
# [220/1800] L1=-1.0002in L2=1.7543in L3=-1.2274in L4=1.2146in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.025546789169311523
# [221/1800] L1=-0.9622in L2=1.3857in L3=-1.5381in L4=0.5815in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 37.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.019165754318237305
# [222/1800] L1=-0.5060in L2=0.6439in L3=-1.4353in L4=0.6702in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.010005950927734375
# [223/1800] L1=-1.1018in L2=1.7457in L3=-1.0611in L4=1.1161in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.005993366241455078
# Time to initialize solution data:0.010988950729370117
# [224/1800] L1=-1.0770in L2=0.5475in L3=-1.2923in L4=1.1359in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 34.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.010383844375610352
# [225/1800] L1=-1.0248in L2=0.5257in L3=-1.6556in L4=0.8674in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.0
#   [checkpoint] wrote 225 rows to hfss_joint_dataset_bandpass_3.csv
# [226/1800] L1=-0.5317in L2=1.3021in L3=-1.8159in L4=1.5298in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015625
# Time to initialize solution data:0.025798797607421875
# [227/1800] L1=-1.4202in L2=1.0432in L3=-1.3256in L4=1.3157in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 38.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.01693272590637207
# [228/1800] L1=-1.6970in L2=1.6095in L3=-1.7635in L4=0.9648in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 36.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.02259683609008789
# [229/1800] L1=-0.5359in L2=0.6756in L3=-1.0904in L4=1.1971in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.015624761581420898
# Time to initialize solution data:0.026368141174316406
# [230/1800] L1=-0.6168in L2=1.0734in L3=-1.1100in L4=0.5379in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 33.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.00599360466003418
# Time to initialize solution data:0.009989738464355469
# [231/1800] L1=-0.8892in L2=0.7134in L3=-1.2479in L4=0.5504in
# PyAEDT INFO: Solving design setup Setup1
# PyAEDT INFO: Design setup Setup1 solved correctly in 0.0h 0.0m 35.0s
# PyAEDT INFO: Solution Data Correctly Loaded.
# Time to initialize solution data:0.0
# Time to initialize solution data:0.0161135196685791
# [232/1800] L1=-1.6225in L2=0.8083in L3=-1.0730in L4=1.3783in

# %%
df = pd.DataFrame(rows, columns=cols)
df.to_csv(OUTPUT_CSV, index=False)
print("\nSaved dataset to:", OUTPUT_CSV)

# %%
hfss.close_desktop()
